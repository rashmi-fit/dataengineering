# %%
import pandas as pd
df = pd.read_excel("/Users/rmn7591/Documents/Repositories/dataengineering/learning_panda/weather_data.xlsx",parse_dates=["day"])

# %%
df.set_index('day',inplace=True)

# %%
df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-02-01           35          7  Sunny
# 2017-03-01           28          2   Snow
# 2017-04-01           24          7   Snow
# 2017-05-01           32          4   Rain
# 2017-06-01           31          2  Sunny

# %%
new_df = df.fillna(0)

# %%
new_df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-02-01           35          7  Sunny
# 2017-03-01           28          2   Snow
# 2017-04-01           24          7   Snow
# 2017-05-01           32          4   Rain
# 2017-06-01           31          2  Sunny

# %%
new_df = df.fillna({
    'temperature':0,
    'windspeed':0,
    'event':'no_event'
})

# %%
new_df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-02-01           35          7  Sunny
# 2017-03-01           28          2   Snow
# 2017-04-01           24          7   Snow
# 2017-05-01           32          4   Rain
# 2017-06-01           31          2  Sunny

# %%
new_df = df.fillna(method="ffill")

# %%
new_df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-02-01           35          7  Sunny
# 2017-03-01           28          2   Snow
# 2017-04-01           24          7   Snow
# 2017-05-01           32          4   Rain
# 2017-06-01           31          2  Sunny

# %%
# interpolate = linear

# %%
new_df = df.interpolate(method= 'time')

# %%
new_df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-02-01           35          7  Sunny
# 2017-03-01           28          2   Snow
# 2017-04-01           24          7   Snow
# 2017-05-01           32          4   Rain
# 2017-06-01           31          2  Sunny
